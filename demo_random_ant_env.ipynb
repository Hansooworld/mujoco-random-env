# %% [markdown]
# #### Import Libraries

# %%
import glfw, os, mujoco_py, warnings, math
warnings.filterwarnings("ignore") # ignore warnings
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import display, HTML
from class_ant import AntRandomEnvClass, AntRandomEnvClassWithBox, AntRandomEnvClassMixVersion
# %matplotlib inline
print ("Done.")
# Out:
# Done.

# %% [markdown]
# #### Random Leg's weight

# %%
max_tick, plot_every = 500, 100
for tick in range(max_tick):
    if (tick+1) % plot_every == 0:
        env = AntRandomEnvClass(xml_path='xml/ant_leg.xml', rand_mass=[1,5], rand_fric=None, render_mode="rgb_array", VERBOSE=False)
        for i in range(10):
            env.step(np.random.standard_normal(8)*0.1)        
        frame = env.render_center()
        plt.figure(figsize=(env.render_w/env.render_res, env.render_h/env.render_res))
        plt.imshow(frame)
        plt.title("Leg Weight [{}]".format(env.get_leg_weight()), fontsize=18)
        plt.show()
# Out:
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw

# %% [markdown]
# #### Set Leg's weight

# %%
max_tick, plot_every = 500, 100
for tick in range(max_tick):
    if (tick+1) % plot_every == 0:
        env = AntRandomEnvClass(xml_path='xml/ant_leg.xml', rand_mass=[1,5], rand_fric=None, render_mode="rgb_array", VERBOSE=False)
        env.set_leg_weight(tick/100)
        frame = env.render(mode='rgb_array')
        for i in range(10):
            env.step(np.random.standard_normal(8)*0.1)        
        plt.figure(figsize=(env.render_w/env.render_res, env.render_h/env.render_res))
        plt.imshow(frame)
        plt.title("Leg Weight [{}]".format(env.get_leg_weight()), fontsize=18)
        plt.show()
# Out:
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw

# %% [markdown]
# #### Random Friction

# %%
for i in range(5):
    env = AntRandomEnvClass(xml_path='xml/ant_leg.xml', rand_mass=None, rand_fric=[0.2, 1.0], render_mode="rgb_array",VERBOSE=False)
    print("Env Friction: [{}]".format(env.get_fric()))
# Out:
# Creating offscreen glfw
# Env Friction: [0.8 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [0.88 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [0.8 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [0.25 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [0.45 0.3 0.3]

# %% [markdown]
# #### Set Friction

# %%
for i in range(5):
    env = AntRandomEnvClass(xml_path='xml/ant_leg.xml', rand_mass=None, rand_fric=[0.2, 1.0], render_mode="rgb_array",VERBOSE=False)
    env.set_fric(i)
    print("Env Friction: [{}]".format(env.get_fric()))
# Out:
# Creating offscreen glfw
# Env Friction: [0 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [1 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [2 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [3 0.3 0.3]
# Creating offscreen glfw
# Env Friction: [4 0.3 0.3]

# %% [markdown]
# #### Random Box's weight

# %%
max_tick, plot_every = 500, 100
for tick in range(max_tick):
    if (tick+1) % plot_every == 0:
        env = AntRandomEnvClassWithBox(xml_path='xml/ant_box.xml', rand_mass=[1,5], rand_fric=None, render_mode="rgb_array",VERBOSE=False)
        for i in range(10):
            env.step(np.random.standard_normal(8)*0.1)
        frame = env.render_center()
        plt.figure(figsize=(env.render_w/env.render_res, env.render_h/env.render_res))
        plt.imshow(frame)
        plt.title("Box Weight [{}]".format(env.get_box_weight()), fontsize=18)
        plt.show()
# Out:
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw

# %% [markdown]
# #### Set Box's weight

# %%
max_tick, plot_every = 500, 100
for tick in range(max_tick):
    if (tick+1) % plot_every == 0:
        env = AntRandomEnvClassWithBox(xml_path='xml/ant_box.xml', rand_mass=[1,5], rand_fric=None, render_mode="rgb_array",VERBOSE=False)
        env.set_box_weight(tick/100)
        for i in range(10):
            env.step(np.random.standard_normal(8)*0.1)
        frame = env.render(mode='rgb_array', width=2000, height=1000)
        plt.figure(figsize=(env.render_w/env.render_res, env.render_h/env.render_res))
        plt.imshow(frame)
        plt.title("Box Weight [{}]".format(env.get_box_weight()), fontsize=18)
        plt.show()
# Out:
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw

# %% [markdown]
# #### Random Box's weight, Leg's weight, Friction

# %%
max_tick, plot_every = 500, 100
env = AntRandomEnvClassMixVersion(xml_path='xml/ant_box_leg.xml', rand_mass_box=[1,5], rand_mass_leg=[1,5], rand_fric=[0.2, 2], render_mode="rgb_array",VERBOSE=True)
for tick in range(max_tick):
    if (tick+1) % plot_every == 0:
        env.reset_random()
        for i in range(10):
            env.step(np.random.standard_normal(8)*0.1)
        frame = env.render_center()
        plt.figure(figsize=(env.render_w/env.render_res, env.render_h/env.render_res))
        plt.imshow(frame)
        plt.title("Box Weight [{}] Leg Weight [{}] Friction [{}]".format(env.get_box_weight(), env.get_leg_weight(), env.get_fric()), fontsize=12)
        plt.show()
# Out:
# Ant(4legs) with random box and leg weights
# Obs Dim: [35] Act Dim: [8] dt:[0.05]
# box_mass:[3.01] leg_mass: [2.31] fric:[1.27 0.3 0.3]
# Creating offscreen glfw
# Ant(4legs) with random box and leg weights
# Obs Dim: [35] Act Dim: [8] dt:[0.05]
# box_mass:[1.92] leg_mass: [1.53] fric:[1.8 0.3 0.3]
# Creating offscreen glfw
# Ant(4legs) with random box and leg weights
# Obs Dim: [35] Act Dim: [8] dt:[0.05]
# box_mass:[3.83] leg_mass: [1.26] fric:[1.58 0.3 0.3]
# Creating offscreen glfw
# Ant(4legs) with random box and leg weights
# Obs Dim: [35] Act Dim: [8] dt:[0.05]
# box_mass:[4.67] leg_mass: [4.95] fric:[0.36 0.3 0.3]
# Creating offscreen glfw
# Ant(4legs) with random box and leg weights
# Obs Dim: [35] Act Dim: [8] dt:[0.05]
# box_mass:[4.88] leg_mass: [4.08] fric:[1.96 0.3 0.3]
# Creating offscreen glfw
# Ant(4legs) with random box and leg weights
# Obs Dim: [35] Act Dim: [8] dt:[0.05]
# box_mass:[3.55] leg_mass: [3.45] fric:[1.84 0.3 0.3]
# Creating offscreen glfw

# %% [markdown]
# #### Set Box's weight, Leg's weight, Friction

# %%
max_tick, plot_every = 500, 100
env = AntRandomEnvClassMixVersion(xml_path='xml/ant_box_leg.xml', rand_mass_box=[1,5], rand_mass_leg=[1,5], rand_fric=[0.2, 2], render_mode="rgb_array",VERBOSE=True)
for tick in range(max_tick):
    if (tick+1) % plot_every == 0:
        env.set_box_weight(tick/100)
        env.set_leg_weight(tick/100)
        env.set_fric(tick/100)
        for i in range(10):
            env.step(np.random.standard_normal(8)*0.1)
        frame = env.render(mode='rgb_array', width=2000, height=1000)
        plt.figure(figsize=(env.render_w/env.render_res, env.render_h/env.render_res))
        plt.imshow(frame)
        plt.title("Box Weight [{}] Leg Weight [{}] Friction [{}]".format(env.get_box_weight(), env.get_leg_weight(), env.get_fric()), fontsize=12)
        plt.show()
# Out:
# Ant(4legs) with random box and leg weights
# Obs Dim: [35] Act Dim: [8] dt:[0.05]
# box_mass:[3.31] leg_mass: [3.72] fric:[0.91 0.3 0.3]
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Creating offscreen glfw
# Context leak detected, msgtracer returned -1
# Creating offscreen glfw
# Creating offscreen glfw
